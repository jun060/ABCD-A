# %% [markdown]
# <a href="https://colab.research.google.com/github/jun060/ABCD-A/blob/20250328/20250328.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000
보유주식 = 10
총평가금액 = (50000 * 10)
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print("시가총액", (시가총액))
print("현재가", (현재가))
print("PER", (PER))
# Out:
# 시가총액 298000000000000
# 현재가 50000
# PER 15.79

# %%
s = "hello!"
t = " python"
print(s+t)
# Out:
# hello! python

# %%
a = 2
b = 3
a + a * b
# Out:
# 8
