# %% [markdown]
# <a href="https://colab.research.google.com/github/jun060/ABCD-A/blob/20250321/test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
1 / 2
# Out:
# 0.5

# %%
4 / 2
# Out:
# 2.0

# %%
7 // 3
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %%
2 ** 10
# Out:
# 1024

# %%
int(5 / 2)
# Out:
# 2

# %%
5 // 2
# Out:
# 2

# %%
divmod(5, 2)
# Out:
# (2, 1)

# %%
quotient, remainder = divmod(5, 2)
print(quotient, remainder)
# Out:
# 2 1

# %%
a = 11 + 2
b = 12 - 2
c = 13 * 2
d = 14 / 2
e = 15 ** 2
f = 16 // 2
g = 17 % 3

print(a, b, c, d, e, f, g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
print("10 == 3 =>", a==b)
print("10 != 3 =>", a!=b)
print("10 > 3 =>", a>b)
print("10 > =3 =>", a>=b)
print("10 < 3 =>", a<b)
print("10 <= 3 =>", a <=b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 > =3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
a = 13
print(bin(a))
print(hex(a))
# Out:
# 0b1101
# 0xd

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)

print('')
print(bin(a))
print(bin(b))
print(bin(a|b))
print('')
print(a|b)

print('')
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)

print('')
print(bin(a))
print(bin(~a))
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9
#
# 0b1101
# 0b1001
# 0b1101
#
# 13
#
# 0b1101
# 0b1001
# 0b100
#
# 4
#
# 0b1101
# -0b1110
