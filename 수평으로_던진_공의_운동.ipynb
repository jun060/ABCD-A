# %% [markdown]
# <a href="https://colab.research.google.com/github/jun060/ABCD-A/blob/20250410/%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# 수평으로 던진 공의 운동

# %%
# 초기속도 입력
v0= float(input())
print("초기속도 : ", v0 , "m/s")
# Out:
# 30
# 초기속도 :  30.0 m/s

# %%
#초기 각도 입력
angle_degree = float(input())
print("초기 각도 : ",angle_degree, "도")

#각도를 radian으로 바꾸기
angle_radian = math.radians(angle_degree)
print("초기 각도 : ", angle_radian, "radian")
# Out:
# 30
# 초기 각도 :  30.0 도
# 초기 각도 :  0.5235987755982988 radian

# %%
# x 성분의 속도를 구하세요
v0x = math.cos(angle_radian) * v0
print("x축의 초기속도 : ", v0x , "m/s")
# Out:
# x축의 초기속도 :  25.98076211353316 m/s

# %%
# y 성분의 속도를 구하세요
v0y = math.sin(angle_radian) * v0
print("y축의 초기 속도 : ", v0y , "m/s")
# Out:
# y축의 초기 속도 :  14.999999999999998 m/s

# %%
# 최고점의 높이를 구하여라.
g = 9.8
H = (v0y ** 2 ) / (2 * g)
print("최고점 높이:", H , "m")
# Out:
# 최고점 높이: 11.47959183673469 m

# %%
#최고점에 도착하는 시간을 구하세요
t_top = v0y/g
print("최고점에 도착하는 시간:", t_top , "초")
# Out:
# 최고점에 도착하는 시간: 1.5306122448979589 초

# %%
#수평으로 이동한 최고 거리를 구하세요
t_total = 2 * t_top
range_ = v0x * t_total
print("수평으로 이동한 최고 거리", range_ , "m")
# Out:
# 수평으로 이동한 최고 거리 79.53294524550965 m

# %%
#지면에 닿을 때의 vx, vy, v를 구하세요
vx = v0x
vy = -v0y
vf = math.sqrt(vx ** 2 + vy ** 2)
print("지면에 닿을 때의 vx :", vx, "m/s")
print("지면에 닿을 때의 vy :", vy, "m/s")
print("지면에 닿을 때의 vf :", vf, "m/s")
# Out:
# 지면에 닿을 때의 vx : 25.98076211353316 m/s
# 지면에 닿을 때의 vy : -14.999999999999998 m/s
# 지면에 닿을 때의 vf : 30.0 m/s
