# %% [markdown]
# <a href="https://colab.research.google.com/github/jun060/ABCD-A/blob/20250406/%EA%B1%B4%EB%AC%BC_%EC%98%A5%EC%83%81%EC%97%90%EC%84%9C_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# 사용자 입력
t = float(input("공이 떨어지기까지 걸린 시간 (초)를 입력하세요: "))
x = float(input("수평 거리 (m)를 입력하세요): "))

# 중력 가속도
g = -9.81  # m/s^2

#공의 처음 속도 (수평속도)
v0 = x / t

#옥상의 높이 (자유낙하 공식 사용)
y = - 1 / 2 * g * t **2

#공이 지면에 닿을 때 속도
vx = v0
vy = g * t

# 최종 속도 크기
v = math.sqrt(vx**2 + vy**2)

# 최종 속도 방향 (아래로 향한 각도, 단위: 도)
theta_rad = math.atan(vy / vx)
theta_deg = math.degrees(theta_rad)

# 결과 출력
print("\n##[결과]")
print(f"a) 공의 처음 속도 크기: {v0:.2f} m/s")
print(f"b) 건물 높이: {y:.2f} m")
print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")
print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# 공이 떨어지기까지 걸린 시간 (초)를 입력하세요: 3
# 수평 거리 (m)를 입력하세요): 50
#
# ##[결과]
# a) 공의 처음 속도 크기: 16.67 m/s
# b) 건물 높이: 44.15 m
# c) 충돌 순간 속도 크기: 33.82 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): -60.48도
